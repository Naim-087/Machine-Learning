# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.9.0-py3-none-any.whl.metadata (15 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.19.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from optuna) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from optuna) (26.3)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.13/dist-packages (from optuna) (2.0.52)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.13/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.13/dist-packages (from alembic>=1.5.0->optuna) (4.16.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.5.5)
# Downloading optuna-4.9.0-py3-none-any.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 7.2 MB/s eta 0:00:00
# Downloading alembic-1.19.1-py3-none-any.whl (265 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 14.7 MB/s eta 0:00:00
# Downloading colorlog-6.12.0-py3-none-any.whl (12 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.19.1 colorlog-6.12.0 optuna-4.9.0

# %%
# Import necessary libraries
import optuna
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the Pima Indian Diabetes dataset from sklearn
# Note: Scikit-learn's built-in 'load_diabetes' is a regression dataset.
# We will load the actual diabetes dataset from an external source
import pandas as pd

# Load the Pima Indian Diabetes dataset (from UCI repository)
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
           'DiabetesPedigreeFunction', 'Age', 'Outcome']

# Load the dataset
df = pd.read_csv(url, names=columns)

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import numpy as np

# Replace zero values with NaN in columns where zero is not a valid value
cols_with_missing_vals = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
df[cols_with_missing_vals] = df[cols_with_missing_vals].replace(0, np.nan)

# Impute the missing values with the mean of the respective column
df.fillna(df.mean(), inplace=True)

# Check if there are any remaining missing values
print(df.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Split into features (X) and target (y)
X = df.drop('Outcome', axis=1)
y = df['Outcome']

# Split data into training and test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Optional: Scale the data for better model performance
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Check the shape of the data
print(f'Training set shape: {X_train.shape}')
print(f'Test set shape: {X_test.shape}')
# Out:
# Training set shape: (537, 8)
# Test set shape: (231, 8)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# Define the objective function
def objective(trial):
    # Suggest values for the hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_depth = trial.suggest_int('max_depth', 3, 20)

    # Create the RandomForestClassifier with suggested hyperparameters
    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=42
    )

    # Perform 3-fold cross-validation and calculate accuracy
    score = cross_val_score(model, X_train, y_train, cv=3, scoring='accuracy').mean()

    return score  # Return the accuracy score for Optuna to maximize

# %%
# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler())  # We aim to maximize accuracy
study.optimize(objective, n_trials=50)  # Run 50 trials to find the best hyperparameters
# Out:
# [I 2026-08-30 05:57:35,410] A new study created in memory with name: no-name-8613b44c-9830-4704-970d-e6cad9cdfd39
# [I 2026-08-30 05:57:40,694] Trial 0 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 162, 'max_depth': 13}. Best is trial 0 with value: 0.7709497206703911.
# [I 2026-08-30 05:57:43,038] Trial 1 finished with value: 0.7653631284916201 and parameters: {'n_estimators': 88, 'max_depth': 19}. Best is trial 0 with value: 0.7709497206703911.
# [I 2026-08-30 05:57:45,404] Trial 2 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 96, 'max_depth': 7}. Best is trial 0 with value: 0.7709497206703911.
# [I 2026-08-30 05:57:47,702] Trial 3 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 79, 'max_depth': 19}. Best is trial 0 with value: 0.7709497206703911.
# [I 2026-08-30 05:57:52,121] Trial 4 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 166, 'max_depth': 20}. Best is trial 0 with value: 0.7709497206703911.
# [I 2026-08-30 05:57:55,390] Trial 5 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 119, 'max_depth': 11}. Best is trial 0 with value: 0.7709497206703911.
# [I 2026-08-30 05:57:57,706] Trial 6 finished with value: 0.7597765363128491 and parameters: {'n_estimators': 148, 'max_depth': 6}. Best is trial 0 with value: 0.7709497206703911.
# [I 2026-08-30 05:57:59,084] Trial 7 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 116, 'max_depth': 10}. Best is trial 0 with value: 0.7709497206703911.
# [I 2026-08-30 05:57:59,566] Trial 8 finished with value: 0.7821229050279331 and parameters: {'n_estimators': 73, 'max_depth': 19}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:00,782] Trial 9 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 196, 'max_depth': 12}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:01,111] Trial 10 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 50, 'max_depth': 15}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:01,436] Trial 11 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 50, 'max_depth': 16}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:01,768] Trial 12 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 50, 'max_depth': 16}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:02,209] Trial 13 finished with value: 0.7672253258845437 and parameters: {'n_estimators': 69, 'max_depth': 15}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:02,647] Trial 14 finished with value: 0.7783985102420857 and parameters: {'n_estimators': 67, 'max_depth': 17}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:03,234] Trial 15 finished with value: 0.7560521415270017 and parameters: {'n_estimators': 106, 'max_depth': 3}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:03,721] Trial 16 finished with value: 0.7802607076350094 and parameters: {'n_estimators': 71, 'max_depth': 18}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:04,509] Trial 17 finished with value: 0.7783985102420856 and parameters: {'n_estimators': 126, 'max_depth': 18}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:05,198] Trial 18 finished with value: 0.7783985102420857 and parameters: {'n_estimators': 71, 'max_depth': 20}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:06,086] Trial 19 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 92, 'max_depth': 14}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:06,931] Trial 20 finished with value: 0.7672253258845437 and parameters: {'n_estimators': 82, 'max_depth': 18}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:07,650] Trial 21 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 68, 'max_depth': 17}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:08,209] Trial 22 finished with value: 0.7765363128491621 and parameters: {'n_estimators': 65, 'max_depth': 17}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:08,874] Trial 23 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 101, 'max_depth': 18}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:09,290] Trial 24 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 59, 'max_depth': 20}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:09,832] Trial 25 finished with value: 0.7635009310986964 and parameters: {'n_estimators': 82, 'max_depth': 16}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:10,308] Trial 26 finished with value: 0.7783985102420856 and parameters: {'n_estimators': 72, 'max_depth': 17}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:10,705] Trial 27 finished with value: 0.7635009310986964 and parameters: {'n_estimators': 60, 'max_depth': 14}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:11,400] Trial 28 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 107, 'max_depth': 19}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:11,896] Trial 29 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 78, 'max_depth': 13}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:12,489] Trial 30 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 88, 'max_depth': 14}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:12,881] Trial 31 finished with value: 0.7653631284916201 and parameters: {'n_estimators': 60, 'max_depth': 20}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:13,375] Trial 32 finished with value: 0.7765363128491621 and parameters: {'n_estimators': 74, 'max_depth': 19}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:13,955] Trial 33 finished with value: 0.7765363128491621 and parameters: {'n_estimators': 89, 'max_depth': 18}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:14,355] Trial 34 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 59, 'max_depth': 20}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:14,949] Trial 35 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 95, 'max_depth': 19}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:15,481] Trial 36 finished with value: 0.7653631284916201 and parameters: {'n_estimators': 78, 'max_depth': 17}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:15,927] Trial 37 finished with value: 0.7783985102420857 and parameters: {'n_estimators': 69, 'max_depth': 20}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:16,753] Trial 38 finished with value: 0.7802607076350093 and parameters: {'n_estimators': 133, 'max_depth': 18}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:17,616] Trial 39 finished with value: 0.7635009310986964 and parameters: {'n_estimators': 137, 'max_depth': 9}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:19,034] Trial 40 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 162, 'max_depth': 18}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:20,916] Trial 41 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 186, 'max_depth': 19}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:22,169] Trial 42 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 175, 'max_depth': 16}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:23,180] Trial 43 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 150, 'max_depth': 19}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:24,031] Trial 44 finished with value: 0.7783985102420856 and parameters: {'n_estimators': 121, 'max_depth': 17}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:24,755] Trial 45 finished with value: 0.7783985102420856 and parameters: {'n_estimators': 111, 'max_depth': 15}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:25,415] Trial 46 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 99, 'max_depth': 20}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:26,289] Trial 47 finished with value: 0.7746741154562383 and parameters: {'n_estimators': 137, 'max_depth': 18}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:26,857] Trial 48 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 83, 'max_depth': 16}. Best is trial 8 with value: 0.7821229050279331.
# [I 2026-08-30 05:58:27,176] Trial 49 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 55, 'max_depth': 3}. Best is trial 8 with value: 0.7821229050279331.

# %%
# Print the best result
print(f'Best trial accuracy: {study.best_trial.value}')
print(f'Best hyperparameters: {study.best_trial.params}')
# Out:
# Best trial accuracy: 0.7821229050279331
# Best hyperparameters: {'n_estimators': 73, 'max_depth': 19}

# %%
from sklearn.metrics import accuracy_score

# Train a RandomForestClassifier using the best hyperparameters from Optuna
best_model = RandomForestClassifier(**study.best_trial.params, random_state=42)

# Fit the model to the training data
best_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = best_model.predict(X_test)

# Calculate the accuracy on the test set
test_accuracy = accuracy_score(y_test, y_pred)

# Print the test accuracy
print(f'Test Accuracy with best hyperparameters: {test_accuracy:.2f}')
# Out:
# Test Accuracy with best hyperparameters: 0.76

# %% [markdown]
# # Sampler In Optuna

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# Define the objective function
def objective(trial):
    # Suggest values for the hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_depth = trial.suggest_int('max_depth', 3, 20)

    # Create the RandomForestClassifier with suggested hyperparameters
    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=42
    )

    # Perform 3-fold cross-validation and calculate accuracy
    score = cross_val_score(model, X_train, y_train, cv=3, scoring='accuracy').mean()

    return score  # Return the accuracy score for Optuna to maximize

# %%
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.RandomSampler())  # We aim to maximize accuracy
study.optimize(objective, n_trials=50)  # Run 50 trials to find the best hyperparameters
# Out:
# [I 2026-08-30 05:59:32,680] A new study created in memory with name: no-name-f9ddb78a-22e5-4ab0-ad78-ce27d197463e
# [I 2026-08-30 05:59:33,367] Trial 0 finished with value: 0.7541899441340781 and parameters: {'n_estimators': 64, 'max_depth': 3}. Best is trial 0 with value: 0.7541899441340781.
# [I 2026-08-30 05:59:35,508] Trial 1 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 197, 'max_depth': 4}. Best is trial 1 with value: 0.7616387337057727.
# [I 2026-08-30 05:59:39,003] Trial 2 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 136, 'max_depth': 5}. Best is trial 2 with value: 0.7690875232774674.
# [I 2026-08-30 05:59:40,217] Trial 3 finished with value: 0.7672253258845437 and parameters: {'n_estimators': 193, 'max_depth': 7}. Best is trial 2 with value: 0.7690875232774674.
# [I 2026-08-30 05:59:40,900] Trial 4 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 110, 'max_depth': 17}. Best is trial 4 with value: 0.7728119180633147.
# [I 2026-08-30 05:59:41,414] Trial 5 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 79, 'max_depth': 16}. Best is trial 4 with value: 0.7728119180633147.
# [I 2026-08-30 05:59:42,626] Trial 6 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 193, 'max_depth': 12}. Best is trial 6 with value: 0.7746741154562384.
# [I 2026-08-30 05:59:43,245] Trial 7 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 96, 'max_depth': 18}. Best is trial 6 with value: 0.7746741154562384.
# [I 2026-08-30 05:59:43,817] Trial 8 finished with value: 0.7560521415270017 and parameters: {'n_estimators': 92, 'max_depth': 6}. Best is trial 6 with value: 0.7746741154562384.
# [I 2026-08-30 05:59:44,560] Trial 9 finished with value: 0.7672253258845437 and parameters: {'n_estimators': 110, 'max_depth': 10}. Best is trial 6 with value: 0.7746741154562384.
# [I 2026-08-30 05:59:45,649] Trial 10 finished with value: 0.7672253258845437 and parameters: {'n_estimators': 186, 'max_depth': 5}. Best is trial 6 with value: 0.7746741154562384.
# [I 2026-08-30 05:59:46,618] Trial 11 finished with value: 0.7635009310986964 and parameters: {'n_estimators': 165, 'max_depth': 6}. Best is trial 6 with value: 0.7746741154562384.
# [I 2026-08-30 05:59:47,246] Trial 12 finished with value: 0.7635009310986964 and parameters: {'n_estimators': 96, 'max_depth': 16}. Best is trial 6 with value: 0.7746741154562384.
# [I 2026-08-30 05:59:48,031] Trial 13 finished with value: 0.7635009310986964 and parameters: {'n_estimators': 122, 'max_depth': 9}. Best is trial 6 with value: 0.7746741154562384.
# [I 2026-08-30 05:59:48,828] Trial 14 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 116, 'max_depth': 13}. Best is trial 6 with value: 0.7746741154562384.
# [I 2026-08-30 05:59:49,565] Trial 15 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 72, 'max_depth': 9}. Best is trial 6 with value: 0.7746741154562384.
# [I 2026-08-30 05:59:52,472] Trial 16 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 195, 'max_depth': 9}. Best is trial 6 with value: 0.7746741154562384.
# [I 2026-08-30 05:59:53,836] Trial 17 finished with value: 0.7783985102420856 and parameters: {'n_estimators': 127, 'max_depth': 15}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 05:59:55,151] Trial 18 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 120, 'max_depth': 16}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 05:59:56,557] Trial 19 finished with value: 0.7597765363128491 and parameters: {'n_estimators': 147, 'max_depth': 4}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 05:59:58,320] Trial 20 finished with value: 0.7635009310986964 and parameters: {'n_estimators': 174, 'max_depth': 6}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 05:59:59,245] Trial 21 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 149, 'max_depth': 14}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 05:59:59,707] Trial 22 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 69, 'max_depth': 16}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 06:00:00,462] Trial 23 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 113, 'max_depth': 12}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 06:00:01,151] Trial 24 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 103, 'max_depth': 7}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 06:00:01,708] Trial 25 finished with value: 0.7523277467411545 and parameters: {'n_estimators': 89, 'max_depth': 3}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 06:00:03,079] Trial 26 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 156, 'max_depth': 6}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 06:00:04,073] Trial 27 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 91, 'max_depth': 16}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 06:00:05,370] Trial 28 finished with value: 0.7653631284916201 and parameters: {'n_estimators': 130, 'max_depth': 6}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 06:00:06,375] Trial 29 finished with value: 0.7635009310986964 and parameters: {'n_estimators': 141, 'max_depth': 14}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 06:00:06,782] Trial 30 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 62, 'max_depth': 8}. Best is trial 17 with value: 0.7783985102420856.
# [I 2026-08-30 06:00:07,266] Trial 31 finished with value: 0.7802607076350094 and parameters: {'n_estimators': 71, 'max_depth': 18}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:07,720] Trial 32 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 71, 'max_depth': 7}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:08,086] Trial 33 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 52, 'max_depth': 12}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:08,623] Trial 34 finished with value: 0.7783985102420856 and parameters: {'n_estimators': 80, 'max_depth': 12}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:09,840] Trial 35 finished with value: 0.7802607076350093 and parameters: {'n_estimators': 194, 'max_depth': 17}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:10,365] Trial 36 finished with value: 0.7672253258845437 and parameters: {'n_estimators': 84, 'max_depth': 8}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:11,504] Trial 37 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 186, 'max_depth': 18}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:12,107] Trial 38 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 95, 'max_depth': 17}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:12,799] Trial 39 finished with value: 0.7709497206703911 and parameters: {'n_estimators': 121, 'max_depth': 5}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:13,921] Trial 40 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 162, 'max_depth': 10}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:14,995] Trial 41 finished with value: 0.7690875232774674 and parameters: {'n_estimators': 162, 'max_depth': 14}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:16,010] Trial 42 finished with value: 0.7783985102420856 and parameters: {'n_estimators': 121, 'max_depth': 16}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:16,547] Trial 43 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 56, 'max_depth': 5}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:17,896] Trial 44 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 136, 'max_depth': 9}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:19,232] Trial 45 finished with value: 0.7616387337057727 and parameters: {'n_estimators': 153, 'max_depth': 9}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:19,892] Trial 46 finished with value: 0.7672253258845437 and parameters: {'n_estimators': 106, 'max_depth': 11}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:21,011] Trial 47 finished with value: 0.7746741154562384 and parameters: {'n_estimators': 171, 'max_depth': 12}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:22,072] Trial 48 finished with value: 0.7728119180633147 and parameters: {'n_estimators': 166, 'max_depth': 14}. Best is trial 31 with value: 0.7802607076350094.
# [I 2026-08-30 06:00:22,912] Trial 49 finished with value: 0.7783985102420856 and parameters: {'n_estimators': 135, 'max_depth': 7}. Best is trial 31 with value: 0.7802607076350094.

# %%
# Print the best result
print(f'Best trial accuracy: {study.best_trial.value}')
print(f'Best hyperparameters: {study.best_trial.params}')
# Out:
# Best trial accuracy: 0.7802607076350094
# Best hyperparameters: {'n_estimators': 71, 'max_depth': 18}

# %%
from sklearn.metrics import accuracy_score

# Train a RandomForestClassifier using the best hyperparameters from Optuna
best_model = RandomForestClassifier(**study.best_trial.params, random_state=42)

# Fit the model to the training data
best_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = best_model.predict(X_test)

# Calculate the accuracy on the test set
test_accuracy = accuracy_score(y_test, y_pred)

# Print the test accuracy
print(f'Test Accuracy with best hyperparameters: {test_accuracy:.2f}')
# Out:
# Test Accuracy with best hyperparameters: 0.74
